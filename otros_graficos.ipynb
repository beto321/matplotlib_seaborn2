# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data=np.random.randint(1,50,100)
data
# Out:
# array([29, 36, 39, 33, 44, 14, 49, 18, 19,  7, 38, 27, 30, 13, 34, 18, 48,
#        40,  1, 48, 29, 43, 37, 41,  1,  6,  9, 42, 12, 20, 21, 26, 17,  6,
#        30, 26, 45, 22,  8, 20, 42, 24, 11, 34, 23, 39,  5, 38, 40, 14,  4,
#         3, 35, 18, 17, 35, 36, 27,  8,  9, 17,  4,  6, 19, 30, 19, 39,  6,
#        16, 37, 46, 33, 23, 38, 18, 10, 13, 18, 12, 42, 28, 43, 33,  9, 12,
#        44, 32, 43, 40,  6,  8, 25, 44, 25, 37, 18, 30, 11, 40, 37])

# %% [markdown]
# ## histograma

# %%
plt.hist(data,bins=50)
plt.show()

# %%
plt.hist(data,bins=50,histtype='step')
plt.show()

# %% [markdown]
# ## Boxplot

# %%
plt.boxplot(data, vert=False, patch_artist=True, notch=True)
plt.show()

# %%
# what happens with outliers?
data=np.append(data,200)
plt.boxplot(data, vert=False, patch_artist=True, notch=True,showfliers=False)

plt.show()

# %% [markdown]
# ## Scaterplot

# %%
N=50
x=np.random.rand(N)
y=np.random.rand(N)
area=(30 * np.random.rand(N))**2
colors=np.random.rand(N)

# %%
plt.scatter (x,y, s=area, c=colors, marker='o', alpha=0.5)
plt.show()
